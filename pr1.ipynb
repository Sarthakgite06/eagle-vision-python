# %%
print("hello world")
# Out:
# hello world

# %%
student = "jay"
print(student);

"for i in range(6):"


    # print(i)
# Out:
# jay
# 'for i in range(6):'

# %%
num1 = 10
num2 = 40
print(num1 + num2)
# how to add two numbers in python
num1 = 3
num2 = 2
sum = num1 + num2
print("sum of two variables is", sum)
# Out:
# 50
# sum of two variables is 5

# %%
# Personal Profile Program

name = "Sarthak Gite"
age = 22
college_name = "Genba Sopanrao Moze College of Engineering"
city = "Pune (Alandi)"
course_name = "AI and DS"
print("name",name)
print("Age", age)
print("College name", college_name)
print("City", city)
print("Course name", course_name)
# Out:
# name Sarthak Gite
# Age 22
# College name Genba Sopanrao Moze College of Engineering
# City Pune (Alandi)
# Course name Artificial Intelligence and Data Science

# %%
# Student Report

student_name = "Sarthak Gite"
roll_number = 17
branch = "AI and DS"
percentage = 86.20
passed = True
print("Student Name", student_name)
print("Roll Number", roll_number)
print("Branch", branch)
print("Percentage", percentage)
print("Passed", passed)
# Out:
# Student Name Sarthak Gite
# Roll Number 17
# Branch Artificial Intelligence and Data Science
# Percentage 86.2
# Passed True

# %%
# Identifiers

student_name = "Sarthak"
roll_no = 17
college_name = "GSMCOE"
course_name = "AI & DS"
cgpa = 8.62
email_id = "sarthakgite006@gmail.com"
mobile_number = 9130383513

print("Student Name", student_name)
print("Roll No", roll_no)
print("College Name", college_name)
print("Course", course_name)
print("CGPA", cgpa)
print("Email", email_id)
print("Mobile", mobile_number)
# Out:
# Student Name Sarthak
# Roll No 17
# College Name GSMCOE
# Course AI & DS
# CGPA 8.62
# Email sarthakgite006@gmail.com
# Mobile 9130383513

# %%
# how to write comments


# print("Student Name", student_name)
# print("Roll No", roll_no)
# print("College Name", college_name)
# print("Course", course_name)
# print("CGPA", cgpa)
# print("Email", email_id)
# print("Mobile", mobile_number)


#  this is multiline comment system


"hi this is sarthak  i am study Agentic Ai for getting placed in good company i really wanted to learn new things which can increase my knowledge"
# Out:
# 'hi this is sarthak  i am study Agentic Ai for getting placed in good company i really wanted to learn new things which can increase my knowledge'

# %%
# correction of variables
student2 = "omkar"
student_name = "Rajesh"
student_full_name = "samadhan"
class_name = "BE Ai and Ds"
for_count = 12
employee_id = 401

print(student2)
print(student_name)
print(class_name)
print(for_count)
print(employee_id)
# Out:
# omkar
# Rajesh
# BE Ai and Ds
# 12
# 401
