# %% [markdown]
# Functional Programing

# %%
def add(num1,num2):
    return num1 + num2
add(29,45)
# Out:
# 74

# %% [markdown]
# 1. Write a program using a lambda function to find the square of each number in a list using map().

# %%
numbers = [1, 2, 3, 4, 5]

square = list(map(lambda i: i * i, numbers))

print(square)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# 2. Write a program using a lambda function to convert all names in a list to uppercase using map().

# %%
names = ["sarthak", "om", "jay"]

upper_names = list(map(lambda i: i.upper(), names))

print(upper_names)
# Out:
# ['SARTHAK', 'OM', 'JAY']

# %% [markdown]
# 3. Write a program using map() to calculate a 10% discount on a list of product prices.

# %%
prices = [100, 200, 300, 400]

discount = list(map(lambda i: i - (i * 10 / 100), prices))

print(discount)
# Out:
# [90.0, 180.0, 270.0, 360.0]

# %% [markdown]
# 4. Write a program using filter() to extract all even numbers from a given list.

# %%
numbers = [1, 2, 3, 4, 5, 6]

even = list(filter(lambda i: i % 2 == 0, numbers))

print(even)
# Out:
# [2, 4, 6]

# %% [markdown]
# 5. Write a program using filter() to display all students who scored 35 or more marks.

# %%
marks = [20, 35, 50, 30, 70, 40]

passed = list(filter(lambda i: i >= 35, marks))

print(passed)
# Out:
# [35, 50, 70, 40]

# %% [markdown]
# 6. Write a program using filter() to remove all empty strings from a list.

# %%
names = ["Sarthak", "", "Om", "", "Jay"]

result = list(filter(lambda i: i != "", names))

print(result)
# Out:
# ['Sarthak', 'Om', 'Jay']

# %% [markdown]
# 7. Write a program using map() to find the length of each string in a list.

# %%
names = ["Sarthak", "Om", "Jay"]

result = list(map(lambda i: len(i), names))

print(result)
# Out:
# [7, 2, 3]

# %% [markdown]
# 8. Write a program using reduce() to calculate the sum of all numbers in a list.

# %%
from functools import reduce

numbers = [1, 2, 3, 4, 5]

result = reduce(lambda i, j: i + j, numbers)

print(result)
# Out:
# 15

# %% [markdown]
# 9. Given a list of employee salaries, use map() to increase each salary by 15%.

# %%
salary = [10000, 20000, 30000, 40000]

new_salary = list(map(lambda i: i + (i * 15 / 100), salary))

print(new_salary)
# Out:
# [11500.0, 23000.0, 34500.0, 46000.0]

# %% [markdown]
# 10. Given a list of integers, use filter() to display only the numbers that are divisible by both 3 and 5.

# %%
numbers = [10, 15, 20, 30, 45, 50, 60]

result = list(filter(lambda i: i % 3 == 0 and i % 5 == 0, numbers))

print(result)
# Out:
# [15, 30, 45, 60]
