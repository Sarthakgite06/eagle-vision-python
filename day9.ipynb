# %% [markdown]
# Iterables and Functions in Python Assignment

# %%
listone = [1,2,3,4,5,6]
# synyax- [experation iteration condition]
# how it run - third       first     second
listtwo = [i**2 for i in listone if i%2 == 0]
print(listtwo)
#  it import because it required contain less line of code
# Out:
# [4, 16, 36]

# %%
set1 = {1,2,3,4,5,6}
set2 = {i/2 for i in set1 if i % 2 == 0}
print(set2)
# Out:
# {1.0, 2.0, 3.0}

# %%
dict1 = {1:1,2:2,3:3,4:4}
dict2 = {i:len(i) for i in dict1.items()}
print(dict2)
# compression
list = [1,2,3,4,5,5,6]
dict1 = {i:i**3 for i in list}
#         expression iteration
print(dict1)
# Out:
# {(1, 1): 2, (2, 2): 2, (3, 3): 2, (4, 4): 2}
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216}

# %% [markdown]
# Assignment 9 Function

# %% [markdown]
# 1. Write a function that accepts two numbers and returns the sum, difference, using multiple return values.

# %%
def sum(a,b):
    return a+b ,a-b,a*b
addition,substraction,multiplication = sum(12,6)
print("sum of a and b is :",addition)
print("subtraction of a and b is :",substraction)
print("multiplication of a and b is :",multiplication)
# Out:
# sum of a and b is : 18
# subtraction of a and b is : 6
# multiplication of a and b is : 72

# %% [markdown]
# 2. Write a function that accepts a list of numbers and returns the largest and smallest number.

# %%
def find_numbers(list1):
    largest = list1[0]
    smallest = list1[0]

    for i in list1:
        if i > largest:
            largest = i

        if i < smallest:
            smallest = i

    print("Largest number is:", largest)
    print("Smallest number is:", smallest)


find_numbers([10, 5, 20, 3, 15])
# Out:
# Largest number is: 20
# Smallest number is: 3

# %% [markdown]
# 3. Write a function using  *args to calculate the sum, average, maximum, and minimum of any number of integers.

# %%
def calculate(*args):
    total = sum(args)
    average = total / len(args)
    maximum = max(args)
    minimum = min(args)

    print("Sum:", total)
    print("Average:", average)
    print("Maximum:", maximum)
    print("Minimum:", minimum)

calculate(10, 20, 30, 40, 50)
# Out:
# Sum: 150
# Average: 30.0
# Maximum: 50
# Minimum: 10

# %% [markdown]
# 4. Write a function using  **kwargs to display employee details (id, name, department, salary) in a formatted manner.

# %%
def employee_info(**kwargs):
    print("employee id:", kwargs["id"])
    print("Employee Name:", kwargs["name"])
    print("Employee Salary:", kwargs["salary"])
    print("Employee Department:", kwargs["department"])

employee_info(id=1, name="sarthak", salary=50000, department="AI and DS")
employee_info(id=2, name="om", salary=60000, department="IT")
employee_info(id=3, name="jay", salary=55000, department="computer science")
# Out:
# employee id: 1
# Employee Name: sarthak
# Employee Salary: 50000
# Employee Department: AI and DS
# employee id: 2
# Employee Name: om
# Employee Salary: 60000
# Employee Department: IT
# employee id: 3
# Employee Name: jay
# Employee Salary: 55000
# Employee Department: computer science

# %% [markdown]
# 5. Write a function that accepts a string and returns the number of uppercase letters, lowercase letters, digits.

# %%
def String(str1):
    uppercase = 0
    lowercase = 0
    for char in str1:
        if char.isupper():
            uppercase += 1
        elif char.islower():
            lowercase += 1
    print("number of uppercase Letters:", uppercase)
    print("number of lowercase Letters:", lowercase)

String("Sarthak")
# Out:
# number of uppercase Letters: 1
# number of lowercase Letters: 6

# %% [markdown]
# 6. Write a function that checks whether a given string is a Palindrome.

# %%
def check_palindrome(Str1):
    reversed_str = Str1[::-1]
    if Str1 == reversed_str:
        print("The string is a palindrome.")
    else:
        print("The string is not a palindrome.")

check_palindrome("nitin")
# Out:
# The string is a palindrome.

# %% [markdown]
# 7. Write a function that accepts a list of integers and returns a new list containing only even numbers.

# %%
def even(num):
    Even = []
    for i in num:
        if i%2 == 0:
            Even.append(i)
    print("Even numbers in the list:", Even)
even((1,2,3,4,5))
# Out:
# Even numbers in the list: [2, 4]

# %% [markdown]
# 8. Create a menu-driven calculator using functions that performs Addition, Subtraction, Multiplication, Division, and Exit.

# %%
def calculator(num1, num2, operation):
    if operation == "add":
        return num1 + num2
    elif operation == "subtract":
        return num1 - num2
    elif operation == "multiply":
        return num1 * num2
    elif operation == "divide":
        if num2 != 0:
            return num1 / num2
        else:
            return "Error: Division by zero"
    else:
        return "Invalid operation"
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
operation = input("Enter operation (add, subtract, multiply, divide): ")
result = calculator(num1, num2, operation)
print("Result:", result)
# Out:
# Result: 25

# %% [markdown]
# 9. Write a function that accepts a dictionary of students and their marks, then returns the name of the topper and the highest marks.

# %%
def top(marks):
    highest_marks = max(marks.values())

    for name in marks:
        if marks[name] == highest_marks:
            print("Topper Name:", name)
            print("Highest Marks:", highest_marks)

top({"sarthak": 90, "om": 85, "jay": 95})
# Out:
# Topper Name: jay
# Highest Marks: 95

# %% [markdown]
# 10. Write a function that accepts a sentence and returns the frequency of each word using a dictionary.

# %%
def frequency_count(string):
    frequency = {}
    for char in string:
        if char in frequency:
            frequency[char] += 1
        else:
            frequency[char] = 1
    return frequency
str1 = "sarthak"
print(frequency_count(str1))
# Out:
# {'s': 1, 'a': 2, 'r': 1, 't': 1, 'h': 1, 'k': 1}

# %% [markdown]
# 11. Write a function that accepts a list of integers and returns:  • Sum of all numbers  • Count of even numbers  • Count of odd numbers

# %%
def check(a):
    even = 0
    odd = 0

    for i in a:
        if i % 2 == 0:
            even += 1
        else:
            odd += 1

    print("Sum:", sum(a))
    print("Even:", even)
    print("Odd:", odd)

check([1, 2, 3, 4, 5])
# Out:
# Sum: 15
# Even: 2
# Odd: 3

# %%
string1 = input("enter sentence:")
v = 0
c = 0
space = 0
for i in string1:
    if i in "aeiou":
        v+=1
    elif i==" ":
        space+=1
    else:
        c+=1
print("vowels:", v)
print("consonants:", c)
print("spaces:", space)
# Out:
# vowels: 2
# consonants: 5
# spaces: 0

# %%
def list2(list1):
    total = sum(list1)
    even_count = 0
    odd_count = 0
    for i in list1:
        if i%2==0:
            even_count += 1
        else:
            odd_count += 1
    print("Even numbers:", even_count)
    print("Odd numbers:", odd_count)
    print("Sum of numbers:", total)
    print("largest number:", max(list1))

list2([1, 2, 3, 4, 5, 6])
# Out:
# Even numbers: 3
# Odd numbers: 3
# Sum of numbers: 21
# largest number: 6

# %%
def greet(name): 
    print("Hello", name) 
greet("user")
# Out:
# Hello user

# %%
def addition():    
    return 10 + 20  
result = addition() 
print(result)
# Out:
# 30

# %%
def calculator(a, b, operation):
    if operation == "add":
        return a + b
    elif operation == "subtract":
        return a - b
    elif operation == "multiply":
        return a * b
    elif operation == "divide":
        if b != 0:
            return a / b
        else:
            return "Error: Division by zero"
    else:
        return "Invalid operation"
print(calculator(10, 5, "subtract"))
# Out:
# 5

# %%
def calculate(a, b):
     return a+b, a-b, a*b, a/b
a = int(input("Enter first number: ")) 
b = int(input("Enter second number: "))   
add, sub, mul, div = calculate(a, b) 
print(add) 
print(sub) 
print(mul) 
print(div)
# Out:
# 57
# -33
# 540
# 0.26666666666666666

# %%
def greet(name="Guest"):     
    print("Welcome",name)  
greet()    
greet("sarthak")
# Out:
# Welcome Guest
# Welcome sarthak

# %%
def total(*num):     
    for i in num:         
        print(i)  
total([10,20,30,40])
# Out:
# [10, 20, 30, 40]

# %%
def student(**employee):     
    print(employee)  
student(name="demo",age=22)  
student(name="Rahul",age=20,city="Pune") 
student(name="jay",age=20,city="Pune")
# Out:
# {'name': 'demo', 'age': 22}
# {'name': 'Rahul', 'age': 20, 'city': 'Pune'}
# {'name': 'jay', 'age': 20, 'city': 'Pune'}

# %%
numbers = [1,2,3,4,5]  
result = list(map(lambda i:i*i, numbers))  
print(result)
# Out:
# [1, 4, 9, 16, 25]
